# %%
import pandas as pd

# %%
path=r'C:\Users\user\Desktop\django_project2-1\myweb\data\data_20240809\final_fclty_detail_20240809.csv'
df=pd.read_csv(path, encoding='utf-8-sig')

# %%
df
# Out:
#         PRFID                PRFNM   PRFPDFROM     PRFPDTO  \
# 0    PF238541        15주년 기념공연, 영웅  2024.05.29  2024.08.11
# 1    PF240002               프랑켄슈타인  2024.06.05  2024.08.25
# 2    PF241301           하데스타운 [서울]  2024.07.12  2024.10.06
# 3    PF242052             베르사유의 장미  2024.07.16  2024.10.13
# 4    PF239123             시카고 [서울]  2024.06.07  2024.09.29
# ..        ...                  ...         ...         ...
# 126  PF172547               빌의 구둣방  2021.03.20  2024.12.31
# 127  PF159714                 세례요한  2019.12.21  2024.08.31
# 128  PF155520              라면에 파송송  2019.10.05  2024.08.31
# 129  PF150471  빨간모자야 조심해! [청주, 세종]  2018.01.26  2024.08.15
# 130  PF145801             반짝반짝 라푼젤  2018.08.01  2024.08.31
#
#                                    PRFCAST          PRFCREW PRFRUNTIME  \
# 0      정성화, 양준모, 민우혁, 김도형, 서영주, 이정열, 최민철 등  윤홍선, 윤호진, 김민영 등    2시간 40분
# 1      유준상, 신성록, 전동석, 박은태, 이해준, 고은성, 이지혜 등  엄홍현, 김지원, 왕용범 등    2시간 55분
# ...
