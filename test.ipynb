# %%
import pandas as pd

# %%
path=r'C:\Users\user\Desktop\django_project2-1\myweb\data\data_20240808\all_detail_list_20240808.csv'

df=pd.read_csv(path, encoding='utf-8-sig')
df
# Out:
#         PRFID                PRFNM   PRFPDFROM     PRFPDTO  \
# 0    PF246147             피터팬 [광주]  2024.08.01  2024.08.31
# 1    PF246133       아기 오리의 모험 [청주]  2024.07.01  2024.08.31
# 2    PF245889            인어공주 [창원]  2024.08.03  2024.08.31
# 3    PF245875          미운아기오리 [여수]  2024.08.03  2024.09.08
# 4    PF245791            어린왕자 [부산]  2024.08.02  2024.09.01
# ..        ...                  ...         ...         ...
# 124  PF172547               빌의 구둣방  2021.03.20  2024.12.31
# 125  PF159714                 세례요한  2019.12.21  2024.08.31
# 126  PF155520              라면에 파송송  2019.10.05  2024.08.31
# 127  PF150471  빨간모자야 조심해! [청주, 세종]  2018.01.26  2024.08.15
# 128  PF145801             반짝반짝 라푼젤  2018.08.01  2024.08.31
#
#                       PRFCAST          PRFCREW PRFRUNTIME    PRFAGE  \
# 0                                                     55분   24개월 이상
# 1          오혜미, 정효진, 박용희, 감창선   박소연, 김란, 오동환 등        40분   24개월 이상
# ...

# %%
df=df[df['PRFID']=='PF239123']

col_names=df.columns.tolist()
vals=df.values.tolist()

col_names
# Out:
# ['PRFID',
#  'PRFNM',
#  'PRFPDFROM',
#  'PRFPDTO',
#  'PRFCAST',
#  'PRFCREW',
#  'PRFRUNTIME',
#  'PRFAGE',
#  'ENTRPSNM',
#  'PCSEGUIDANCE',
#  'POSTER',
#  'RELATES',
#  'PLACEID',
#  'PLACENM',
#  'INFO URLS']

# %%
test_dict={col : val for col, val in zip(col_names, vals[0])}

# %%
path=r'C:\Users\user\Desktop\django_project2-1\myweb\data\data_20240808\test_boxof_month_20240808.csv'
df=pd.read_csv(path, encoding='utf-8-sig')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PRFID         129 non-null    object
#  1   PRFNM         129 non-null    object
#  2   PRFPDFROM     129 non-null    object
#  3   PRFPDTO       129 non-null    object
#  4   PRFCAST       129 non-null    object
#  5   PRFCREW       129 non-null    object
#  6   PRFRUNTIME    129 non-null    object
#  7   PRFAGE        129 non-null    object
#  8   ENTRPSNM      129 non-null    object
#  9   PCSEGUIDANCE  129 non-null    object
#  10  POSTER        129 non-null    object
#  11  RELATES       129 non-null    object
#  12  PLACEID       129 non-null    object
#  13  PLACENM       129 non-null    object
#  14  INFO URLS     129 non-null    object
#  15  7DAYS RANK    28 non-null     float64
#  16  30DAYS RANK   30 non-null     float64
# dtypes: float64(2), object(15)
# ...

# %%
df[['30DAYS RANK']]
# Out:
#      30DAYS RANK
# 0       5.233333
# 1       8.733333
# 2      12.066667
# 3      13.266667
# 4      13.538462
# ..           ...
# 124          NaN
# 125          NaN
# 126          NaN
# 127          NaN
# 128          NaN
#
# [129 rows x 1 columns]
